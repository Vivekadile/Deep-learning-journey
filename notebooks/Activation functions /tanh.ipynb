# %% [markdown]
# Tanh

# %% [markdown]
# ![image.png](attachment:176274d2-6540-40e5-8b20-618bd76b4079.png)

# %%
import math
def tanh(x):
    return (math.exp(x)-math.exp(-x))/(math.exp(x)+math.exp(-x))

# %%
tanh(100)
# Out:
# 1.0

# %%
tanh(2)
# Out:
# 0.964027580075817

# %% [markdown]
# ![image.png](attachment:fdd57800-805c-4aea-ab75-4a8b741d5c90.png)
