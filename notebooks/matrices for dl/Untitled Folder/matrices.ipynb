# %%
import math

# %%
import numpy as np

# %%
revenue=np.array([[100,200,220],[24,36,40],[12,18,20]])
revenue
# Out:
# array([[100, 200, 220],
#        [ 24,  36,  40],
#        [ 12,  18,  20]])

# %%
expenses=np.array([[80,90,100],[10,16,20],[8,10,10]])
expenses
# Out:
# array([[ 80,  90, 100],
#        [ 10,  16,  20],
#        [  8,  10,  10]])

# %%
profit= revenue - expenses
profit
# Out:
# array([[ 20, 110, 120],
#        [ 14,  20,  20],
#        [  4,   8,  10]])

# %%
price=np.array([1000,400,1200])
price
# Out:
# array([1000,  400, 1200])

# %%
units=np.array([[30,40,50],[5,10,15],[2,5,7]])
units
# Out:
# array([[30, 40, 50],
#        [ 5, 10, 15],
#        [ 2,  5,  7]])

# %%
price*units
# Out:
# array([[30000, 16000, 60000],
#        [ 5000,  4000, 18000],
#        [ 2000,  2000,  8400]])

# %% [markdown]
# why because it is numpy boracd casting it has taken value fromanother colums

# %%
np.dot(price,units)
# Out:
# array([34400, 50000, 64400])

# %%
rev=np.array([[200,220,250],[68,79,105],[110,140,180],[80,85,90]])
rev
# Out:
# array([[200, 220, 250],
#        [ 68,  79, 105],
#        [110, 140, 180],
#        [ 80,  85,  90]])

# %%
price=75

# %%
rev*price
# Out:
# array([[15000, 16500, 18750],
#        [ 5100,  5925,  7875],
#        [ 8250, 10500, 13500],
#        [ 6000,  6375,  6750]])
